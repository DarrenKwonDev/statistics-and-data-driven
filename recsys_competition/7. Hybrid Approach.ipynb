# %% [markdown]
# # [0] 미션 설명
#
# 다양한 Hybrid Approach에 대해 알고, 이를 직접 코드로 작성해 본다.
#
# > **학습 목표**
# > - 추천에서의 앙상블 방법인
#  Hybrid Approach에 대해 확인한다.
# > - 여러 모델들을 구현하고 이를 앙상블하는 흐름을 배운다.
# > - 하이브리드 접근법 중, 일부를 코드로 작성하여 본다.

# %% [markdown]
# RecSys 기초 대회 강의에서는 Book Crossing 데이터를 사용하여 모든 실습 및 미션, 대회를 진행합니다. [Kaggle Book-Crossing](https://www.kaggle.com/datasets/ruchi798/bookcrossing-dataset) 을 출처로 하며, 데이터는 재구성되어 제공되었습니다. 해당 데이터는 CC0: Public Domain 라이센스임을 밝힙니다.
#
# 그럼 본격적으로 **(미션-3) Hybrid Approach** 를 진행하여 보겠습니다.

# %%
# install packages
# !pip install catboost -q
# !pip install scikit-surprise -q

# %%
# import packages
import pandas as pd
import numpy as np
import warnings

import re
from pandas.api.types import CategoricalDtype
from scipy import sparse
from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import train_test_split

from xgboost import XGBRegressor, XGBClassifier
from lightgbm import LGBMRegressor, LGBMClassifier, LGBMRanker
from catboost import CatBoostRegressor, CatBoostClassifier, Pool

from surprise import Dataset, Reader, accuracy, SVD, KNNBasic, CoClustering
from surprise.dataset import DatasetAutoFolds

import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # [1] Hybrid Approach 이란?
#
# 추천 시스템은 사용자의 취향을 예측하여 가장 적절한 결과를 추천하기 위한 목적이 있습니다.
# 그러나 이 때, 단일 모델만으로 가장 적합한 결과를 만들어 내기 어렵습니다. 각 모델이 활용하는 feature, 잘 작동하는 상황 등이 모두 다르기 때문입니다.
#
# 하이브리드 접근법이란 이를 보완하기 위해 여러 모델을 결합하여, 결과를 도출하는 것을 의미합니다. 이를 통해 각 모델의 장점을 사용하여 다른 모델의 단점을 상쇄, 즉 상호 보완하여 성능을 끌어 올릴 수 있습니다.
#
# 대부분의 추천 시스템은 단일 모델만으로 추천을 진행한다기 보단, 하이브리드 접근법을 사용합니다.
# 하이브리드 접근법은 4강, 5강에서 언급한 바와 같이, Collaborative Filtering, Content Based recommend 등 여러 모델을 결합하는 것을 의미합니다.

# %% [markdown]
# 하이브리드 접근법은 크게 3가지 대분류와 7가지 종류로 확인할 수 있습니다.
#
# 1. Monolithic hybrid designs
# > 다양한 feature를 활용하는 단일 모델
#   - Feature combination
#   - Feature Augmentation
# 2. Parallelized hybrid design
# > 여러 추천 시스템 간의 병렬적인 사용
#   - Weighted
#   - Switching
#   - Mixed
# 3. Pipelined hybrid designs
# > 후속 입력을 위해 일부 입력을 사전 처리하는 방식
#   - Cascade
#   - Meta‐level

# %% [markdown]
# # [2] 하이브리드 접근법의 종류
# 다양한 방식으로 여러 추천 시스템 기법을 결합하여 사용자의 취향을 효과적으로 예측할 수 있습니다.

# %% [markdown]
# ## (1) Monolithic hybrid designs

# %% [markdown]
# ### Feature combine
#
# > 협업 필터링 추천 시스템의 결과를 콘텐츠 기반 추천 시스템 속성의 일부로 사용하는 방식
#
# <div>
# <img src="https://miro.medium.com/max/1400/1*K4ZRADAka8DUM3xh8H76DQ.jpeg"
# width="700"/>
# </div>
#
# [출처](https://medium.com/analytics-vidhya/7-types-of-hybrid-recommendation-system-3e4f78266ad8)
#
#
# - 예를 들어, 서로 다른  소스에서 파생된 feature가 함께 결합되어 단일 추천 알고리즘에 제공됩니다.
# - 사용한 콘텐츠 기반 추천 시스템에 적용하기 전에, 다양한 sources들을 단일된 표현으로 통합합니다.
# - 아이템의 내재적인 정보를 이용함으로서 협업 필터링이 가진 단점을 상쇄합니다.

# %% [markdown]
# ### Feature argument
# > 한 추천시스템의 결과를 다음 추천시스템의 입력값으로 사용하는 방식
# <div>
# <img src="https://miro.medium.com/max/1400/1*1O_Ve4JyETRCybwT6-1ErA.jpeg"
# width="700"/>
# </div>
#
# [출처](https://medium.com/analytics-vidhya/7-types-of-hybrid-recommendation-system-3e4f78266ad8)
#
# - staking 방식과 비슷한 방식으로 이루어 집니다.
# - 예를 들어, 협업 필터링 추천 시스템의 결과를 콘텐츠 기반 추천 시스템의 입력값으로 사용합니다.
# - 1단계의 추천시스템이 features를 만들어서 2단계(Main)의 추천시스템의 입력 값으로 사용합니다.
#
# - 예시 `CB → CF`
#   1. ratings matrix에서 결측치를 콘텐츠 기반 추천 시스템으로 채웁니다.
#   2. 새롭게 채워진 ratings들을 pseudo-ratings라고 하며, 이렇게 채워진 dense ratings 행렬을 사용해 ratings을 예측합니다.

# %% [markdown]
# ## (2) Parallelized hybrid design

# %% [markdown]
# ### Weighted
# > Soft Ensemble 또는 Hard Vote와 같은 방법으로 여러 모델의 추천 결과를 하나로 합쳐 최종 추천 아이템을 정하는 방식
#
# <div>
# <img src="https://miro.medium.com/max/1400/1*N9TO6n2tlo1sN8GhsB-tqw.jpeg"
# width="700"/>
# </div>
#
# [출처](https://medium.com/analytics-vidhya/7-types-of-hybrid-recommendation-system-3e4f78266ad8)
#
# - 가장 보편적인 앙상블 방식
# - 각 모델의 추천 결과를 구하고, 가중치, 투표 등의 방법을 통해 최종 결과 산출

# %% [markdown]
# ### Switching
# > 플랫폼 내 사용자 또는 서비스 상태 등 특정 상황을 고려하여 여러 추천 알고리즘의 추천 결과를 선택적으로 보여주는 방식
# <div>
# <img src="https://miro.medium.com/max/1400/1*oyZqArrmwxb5n-sshMzq-w.jpeg" width="700"/>
# </div>
#
# [출처](https://medium.com/analytics-vidhya/7-types-of-hybrid-recommendation-system-3e4f78266ad8)
#
#
# - 사용하는 추천시스템 모델을 n개 만들고 랜덤 혹은 일정 기준에 맞춰 모델을 변경하여 추천
# - 예를 들어, 사용자가 특정 아이템을 구매하면, 해당 아이템과 유사한 아이템을 추천하는 모델을 사용하고, 사용자가 특정 아이템을 구매하지 않으면, 다른 모델을 사용하여 추천

# %% [markdown]
# ### Mixed
# > 서로 다른 추천에서 나오는 결과물을 섞어서 제공하는 방식
#
# <div>
# <img src="https://miro.medium.com/max/1400/1*jcpCf-mfB4AI7JL7x6WmqA.jpeg"
# width="700"/>
# </div>
#
# [출처](https://medium.com/analytics-vidhya/7-types-of-hybrid-recommendation-system-3e4f78266ad8)
#
# - 여러 추천 시스템의 결과를 활용하고, 이 때 알고리즘의 추천 결과를 모두 보여주는 방식
# - 사용자 수준에서 다양한 추천 시스템의 결과를 결합합니다.
# - 다양한 추천 결과를 제공하여 사용자의 취향을 더 잘 파악할 수 있습니다.

# %% [markdown]
# ## (3) Pipelined hybrid designs

# %% [markdown]
# ### Cascade
# > 추천시스템이 다른 추천시스템에 의해 정제된 아이템을 추천하는 방식
# <div>
# <img src="https://miro.medium.com/max/1400/1*e2oXjzfycXx8WuUMiFmUHA.jpeg"
# width="700"/>
# </div>
#
# [출처](https://medium.com/analytics-vidhya/7-types-of-hybrid-recommendation-system-3e4f78266ad8)
#
#
# - cascade 방식은 boosting에 가까운 형식입니다.
# - 첫 번째 단계에서는 사용자가 좋아할 만한 아이템의 대략적인 범위를 파악합니다.
# - 두 번째 단계에서는 첫 번째 단계에서 추천된 아이템들을 사용자에게 보여주고, 사용자가 좋아할 만한 아이템을 선택하도록 합니다.
#
# 예를 들어,
#     - 1차 모델(Knowledge Based model)을 통해 추천 가능한 항목들로 스크리닝하고,
#     - 2차 모델이 점수를 부여(rescore) 하며, 정제된 아이템을 추천합니다.

# %% [markdown]
# ### Meta-level
# > 하나의 추천 기법이 적용되어 일종의 모델을 생성하고, 이는 다음 기법에서 사용되는 입력입니다.

# %% [markdown]
# 이 중,
# Paralled Hybrid Approach 인 Mixed, Weighted 방법론과 Monolitic Hybrid Approach의 한 종류인 Feature combine에 대해 알아보겠습니다.

# %% [markdown]
# # [3] 데이터 불러오기

# %% [markdown]
# 먼저, 데이터셋을 가져 옵니다. 미션용으로 샘플링된 데이터를 이용하며, 아래 코드를 통해 불러올 수 있습니다.

# %%
# !wget --load-cookies ~/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies ~/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=17Zbpx_Yn0ggLFVeijUalcnOUt5mCHeEH' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=17Zbpx_Yn0ggLFVeijUalcnOUt5mCHeEH" -O users.csv && rm -rf ~/cookies.txt
# !wget --load-cookies ~/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies ~/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1JIxWPgC8JJkuZaWjk5FJBBKuqSX87HGE' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1JIxWPgC8JJkuZaWjk5FJBBKuqSX87HGE" -O books.csv && rm -rf ~/cookies.txt
# !wget --load-cookies ~/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies ~/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1B-8lw3a1KPJdhFAMXP58a7taJjpDvfw6' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1B-8lw3a1KPJdhFAMXP58a7taJjpDvfw6" -O ratings.csv && rm -rf ~/cookies.txt
# Out:
# --2023-03-15 14:37:16--  https://docs.google.com/uc?export=download&confirm=&id=17Zbpx_Yn0ggLFVeijUalcnOUt5mCHeEH
# Resolving docs.google.com (docs.google.com)... 74.125.31.138, 74.125.31.100, 74.125.31.102, ...
# Connecting to docs.google.com (docs.google.com)|74.125.31.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-08-58-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5pnuv4fbqb4558bm02l4c8rhjdcd5n8u/1678890975000/01233170983161563057/*/17Zbpx_Yn0ggLFVeijUalcnOUt5mCHeEH?e=download&uuid=55b61936-7de7-4a8b-8786-235661521b6e [following]
# Warning: wildcards not supported in HTTP.
# --2023-03-15 14:37:17--  https://doc-08-58-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5pnuv4fbqb4558bm02l4c8rhjdcd5n8u/1678890975000/01233170983161563057/*/17Zbpx_Yn0ggLFVeijUalcnOUt5mCHeEH?e=download&uuid=55b61936-7de7-4a8b-8786-235661521b6e
# Resolving doc-08-58-docs.googleusercontent.com (doc-08-58-docs.googleusercontent.com)... 108.177.12.132, 2607:f8b0:400c:c08::84
# Connecting to doc-08-58-docs.googleusercontent.com (doc-08-58-docs.googleusercontent.com)|108.177.12.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 569681 (556K) [text/csv]
# Saving to: ‘users.csv’
#
# users.csv           100%[===================>] 556.33K  --.-KB/s    in 0.005s
#
# 2023-03-15 14:37:17 (111 MB/s) - ‘users.csv’ saved [569681/569681]
#
# --2023-03-15 14:37:18--  https://docs.google.com/uc?export=download&confirm=&id=1JIxWPgC8JJkuZaWjk5FJBBKuqSX87HGE
# Resolving docs.google.com (docs.google.com)... 74.125.31.138, 74.125.31.100, 74.125.31.102, ...
# Connecting to docs.google.com (docs.google.com)|74.125.31.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-04-58-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/imd0mrlkqkf6i3spilsgr11h0vu0lrpj/1678890975000/01233170983161563057/*/1JIxWPgC8JJkuZaWjk5FJBBKuqSX87HGE?e=download&uuid=e261cf0e-7608-45e7-ab93-2a0e561e5738 [following]
# Warning: wildcards not supported in HTTP.
# --2023-03-15 14:37:19--  https://doc-04-58-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/imd0mrlkqkf6i3spilsgr11h0vu0lrpj/1678890975000/01233170983161563057/*/1JIxWPgC8JJkuZaWjk5FJBBKuqSX87HGE?e=download&uuid=e261cf0e-7608-45e7-ab93-2a0e561e5738
# Resolving doc-04-58-docs.googleusercontent.com (doc-04-58-docs.googleusercontent.com)... 108.177.12.132, 2607:f8b0:400c:c08::84
# Connecting to doc-04-58-docs.googleusercontent.com (doc-04-58-docs.googleusercontent.com)|108.177.12.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8758042 (8.4M) [text/csv]
# Saving to: ‘books.csv’
#
# books.csv           100%[===================>]   8.35M  --.-KB/s    in 0.06s
#
# 2023-03-15 14:37:19 (143 MB/s) - ‘books.csv’ saved [8758042/8758042]
#
# --2023-03-15 14:37:20--  https://docs.google.com/uc?export=download&confirm=&id=1B-8lw3a1KPJdhFAMXP58a7taJjpDvfw6
# Resolving docs.google.com (docs.google.com)... 74.125.31.138, 74.125.31.100, 74.125.31.102, ...
# Connecting to docs.google.com (docs.google.com)|74.125.31.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-58-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/38h2gl6ehslu0u5oupbd3hjslpmfqiab/1678890975000/01233170983161563057/*/1B-8lw3a1KPJdhFAMXP58a7taJjpDvfw6?e=download&uuid=63e8f90b-2436-4a5f-8af7-3da662ffb159 [following]
# Warning: wildcards not supported in HTTP.
# --2023-03-15 14:37:21--  https://doc-0k-58-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/38h2gl6ehslu0u5oupbd3hjslpmfqiab/1678890975000/01233170983161563057/*/1B-8lw3a1KPJdhFAMXP58a7taJjpDvfw6?e=download&uuid=63e8f90b-2436-4a5f-8af7-3da662ffb159
# Resolving doc-0k-58-docs.googleusercontent.com (doc-0k-58-docs.googleusercontent.com)... 108.177.12.132, 2607:f8b0:400c:c08::84
# Connecting to doc-0k-58-docs.googleusercontent.com (doc-0k-58-docs.googleusercontent.com)|108.177.12.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3418379 (3.3M) [text/csv]
# Saving to: ‘ratings.csv’
#
# ratings.csv         100%[===================>]   3.26M  --.-KB/s    in 0.02s
#
# 2023-03-15 14:37:21 (207 MB/s) - ‘ratings.csv’ saved [3418379/3418379]

# %%
books = pd.read_csv('./books.csv')
users = pd.read_csv('./users.csv')
ratings = pd.read_csv('./ratings.csv')

# %%
books.shape, users.shape, ratings.shape
# Out:
# ((27013, 10), (14348, 3), (164729, 3))

# %% [markdown]
# book에 대한 전처리를 진행합니다.
# 먼저, 아이디에 대해 처리를 해줍니다.

# %%
books['isbn'] = books['img_url'].apply(lambda x: x.split('P/')[1][:10])

# %% [markdown]
# 각각의 데이터 프레임을 확인합니다.

# %%
print("<<< Dataframe users Example >>>")
print('users shape:\n', users.shape)
print('\ncol nunique:\n', users.nunique(),end='\n\n')
display(users.head(3))
# Out:
# <<< Dataframe users Example >>>
# users shape:
#  (14348, 3)
#
# col nunique:
#  user_id     14348
# location     6034
# age            83
# dtype: int64
#    user_id                  location   age
# 0        8  timmins, ontario, canada   NaN
# 1    11400   ottawa, ontario, canada  49.0
# 2    11676             n/a, n/a, n/a   NaN

# %%
print("<<< Dataframe books Example >>>")
print('books shape:\n', books.shape)
print('\ncol nunique:\n', books.nunique(),end='\n\n')
display(books.head(3))
# Out:
# <<< Dataframe books Example >>>
# books shape:
#  (27013, 10)
#
# col nunique:
#  isbn                   27013
# book_title             24517
# book_author             9157
# year_of_publication       70
# publisher               1507
# img_url                27013
# language                   9
# category                 747
# img_path               27013
# summary                17651
# dtype: int64
#          isbn                                         book_title  \
# 0  0002005018                                       Clara Callan
# 1  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 2  0771074670                        Nights Below Station Street
#
#             book_author  year_of_publication              publisher  \
# 0  Richard Bruce Wright               2001.0  HarperFlamingo Canada
# 1      Gina Bari Kolata               1999.0   Farrar Straus Giroux
# 2  David Adams Richards               1988.0        Emblem Editions
#
#                                              img_url language       category  \
# 0  http://images.amazon.com/images/P/0002005018.0...       en  ['Actresses']
# 1  http://images.amazon.com/images/P/0374157065.0...       en    ['Medical']
# 2  http://images.amazon.com/images/P/0771074670.0...       en    ['Fiction']
#
#                                         img_path  \
# 0  images/___000001___0002005018.01.THUMBZZZ.jpg
# 1  images/___000003___0374157065.01.THUMBZZZ.jpg
# 2  images/___000010___0771074670.01.THUMBZZZ.jpg
#
#                                              summary
# 0  In a small town in Canada, Clara Callan reluct...
# 1  Describes the great flu epidemic of 1918, an o...
# 2  Another story based in the fictional rural tow...

# %%
print("<<< Dataframe ratings >>>")
print('ratings shape:\n', ratings.shape)
print('\ncol nunique:\n', ratings.nunique(),end='\n\n')
display(ratings.head(3))
# Out:
# <<< Dataframe ratings >>>
# ratings shape:
#  (164729, 3)
#
# col nunique:
#  user_id    14110
# isbn       20871
# rating        10
# dtype: int64
#    user_id        isbn  rating
# 0        8  0771074670       1
# 1        8  0002005018       5
# 2       17  0684823802       1

# %% [markdown]
# # [4] 데이터 가공하기

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# 고유 번호인 user_id와 isbn 대신 사용하기 편하게 인덱싱 처리를 해줍니다.

# %%
user2idx = {v:k for k,v in enumerate(ratings['user_id'].unique())}
book2idx = {v:k for k,v in enumerate(ratings['isbn'].unique())}

ratings['iid'] = ratings['isbn'].map(book2idx)
ratings['uid'] = ratings['user_id'].map(user2idx)

# %%
ratings.head(3)
# Out:
#    user_id        isbn  rating  iid  uid
# 0        8  0771074670       1    0    0
# 1        8  0002005018       5    1    0
# 2       17  0684823802       1    2    1

# %% [markdown]
# 이 때, 각 데이터 프레임에 존재하는 결측치를 -1로 채워 줍니다.

# %%
print('books 데이터 프레임의 결측치')
books.isnull().sum()
# Out:
# books 데이터 프레임의 결측치
# isbn                      0
# book_title                0
# book_author               0
# year_of_publication       0
# publisher                 0
# img_url                   0
# language               8932
# category               9066
# img_path                  0
# summary                8932
# dtype: int64

# %%
print('users 데이터 프레임의 결측치')
users.isnull().sum()
# Out:
# users 데이터 프레임의 결측치
# user_id        0
# location       0
# age         4501
# dtype: int64

# %%
print('ratings 데이터 프레임의 결측치')
ratings.isnull().sum()
# Out:
# ratings 데이터 프레임의 결측치
# user_id    0
# isbn       0
# rating     0
# iid        0
# uid        0
# dtype: int64

# %%
books.fillna(-1,inplace=True)
users.fillna(-1,inplace=True)
ratings.fillna(-1,inplace=True)

# %% [markdown]
# user-item에 대한 interaction matrix를 만들어 줍니다.
# 메모리 관리를 위해 pivot 대신 coo matrix로 만듭니다.

# %%
from pandas.api.types import CategoricalDtype
from scipy import sparse

size_uid = ratings["uid"].unique()
size_iid = ratings["iid"].unique()

ui_shape = (len(size_uid), len(size_iid))

user_cat = CategoricalDtype(categories=sorted(size_uid), ordered=True)
book_cat = CategoricalDtype(categories=sorted(size_iid), ordered=True)

user_index = ratings["uid"].astype(user_cat).cat.codes
book_index = ratings["iid"].astype(book_cat).cat.codes

interactions = sparse.coo_matrix((ratings["rating"], (user_index,book_index)), shape=ui_shape)

# %%
interactions
# Out:
# <14110x20871 sparse matrix of type '<class 'numpy.int64'>'
# 	with 164729 stored elements in COOrdinate format>

# %% [markdown]
# spare한 정도를 확인하여 봅시다.

# %%
def check_sparsity(interactions:sparse.coo_matrix)->int:
  matrix_size = interactions.shape[0]*interactions.shape[1] # Number of possible interactions in the matrix
  num_purchases = len(interactions.nonzero()[0]) # Number of items interacted with
  sparsity = 100*(1 - (num_purchases/matrix_size))
  return round(sparsity,4)

# %%
print(f"matrix sparsity : {check_sparsity(interactions)}%")
# Out:
# matrix sparsity : 99.9441%

# %% [markdown]
# ### Train/Test Split (Interaction)

# %% [markdown]
# Train, Test를 분할합니다.
#
# - 행렬에서 0이 아닌 즉, 평가 기록이 있는 데이터
# 를 랜덤하게 Train, Test 로 나눠 줍니다.
# - data를 shuffle한 후, 유저를 기준으로 나눕니다.

# %%
def shuffle_data(interactions:sparse.coo_matrix, random_state:int=42)->tuple:
    random_state = np.random.RandomState(seed=random_state)

    interactions = interactions.tocoo()

    uids, iids, data = (interactions.row, interactions.col, interactions.data)

    shuffle_indices = np.arange(len(uids))
    random_state.shuffle(shuffle_indices)

    uids = uids[shuffle_indices]
    iids = iids[shuffle_indices]
    data = data[shuffle_indices]

    return uids, iids, data

# %%
def cutoff_by_user(uids:list, test_percentage:float=0.2):
    cutoff = int((1.0 - test_percentage) * len(uids))
    train_idx = slice(None, cutoff)
    test_idx = slice(cutoff, None)
    return train_idx, test_idx

# %% [markdown]
# 추가로 위치에 맞게 평가 기록을 추가하는 코드를 작성합니다.

# %%
def random_train_test_split(interactions, test_percentage=0.2, valid=None, random_state=42):
    uids, iids, data = shuffle_data(interactions, random_state)
    train_idx, test_idx = cutoff_by_user(uids, test_percentage)
    shape = interactions.shape

    train = sparse.coo_matrix(
        (data[train_idx], (uids[train_idx], iids[train_idx])),
        shape=shape,
        dtype=interactions.dtype,
    )
    test = sparse.coo_matrix(
        (data[test_idx], (uids[test_idx], iids[test_idx])),
        shape=shape,
        dtype=interactions.dtype,
    )
    return train, test

# %%
train, test = random_train_test_split(interactions,test_percentage=0.2,random_state=42)

# %% [markdown]
# 라이브러리에서 원활한 사용을 위해 csr_matrix로 변환하여 줍니다.

# %%
train = train.tocsr()
test = test.tocsr()

# %%
train, test
# Out:
# (<14110x20871 sparse matrix of type '<class 'numpy.int64'>'
#  	with 131783 stored elements in Compressed Sparse Row format>,
#  <14110x20871 sparse matrix of type '<class 'numpy.int64'>'
#  	with 32946 stored elements in Compressed Sparse Row format>)

# %% [markdown]
# ### Train/Test Split (DataFrame)

# %% [markdown]
# GBDT 모델도 사용하기 위해 데이터프레임도 만들겠습니다.
# random_train_test_split에서 사용하였던 데이터와 동일하게 사용합니다.

# %%
uids, iids, data = shuffle_data(interactions)
train_idx, test_idx = cutoff_by_user(uids)

train_df = pd.DataFrame({'uid':uids[train_idx], 'iid':iids[train_idx], 'ratings':data[train_idx]})
test_df = pd.DataFrame({'uid':uids[test_idx], 'iid':iids[test_idx], 'ratings':data[test_idx]})

# %% [markdown]
# 앞서 제작한 매트릭스의 stored elements 갯수와 shape[0]이 같음을 확인할 수 있습니다.

# %%
train_df.shape, test_df.shape
# Out:
# ((131783, 3), (32946, 3))

# %%
train_df.head()
# Out:
#      uid    iid  ratings
# 0   2238   3787        8
# 1   5741  17589        1
# 2    109    976        6
# 3  12244   6379        5
# 4  10754   8920        8

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# contents based recommender 모델을 위한 여러 feature를 생성합니다.

# %% [markdown]
# ### User
# user에서부터 파생된 feature로 location, age를 사용하여, 모델 생성 예정으로 이를 처리합니다.

# %%
users_location = pd.concat(
    [users.drop('location', axis=1), 
     (users['location'].str.split(',', expand=True)
     .assign(location_country = lambda x : np.where(x[2]=='', x[3], x[2]),
            location_state = lambda x : x[1],
            location_city = lambda x : x[0],
            ) 
      )[['location_country', 'location_state', 'location_city']]
     ], axis=1)

city_tab = pd.DataFrame([['iowa city','iowa','usa'],
['somerset', 'somerset','england'],
['milford','massachusetts','usa'],
['rockvale','tennessee','usa'],
['bronx','newyork','usa'],
['tustin','california','usa'],
['choctaw','choctaw','usa'],
['richmond hill','richmond hill','canada'],
['kuala lumpur','kuala lumpur','malaysia']])
city_tab.columns = ['city','state','country']

for _,row in city_tab.iterrows():
    location_idx = users_location['location_city'] == row.city
    users_location.loc[location_idx,'location_city'] = row.city
    users_location.loc[location_idx,'location_state'] = row.state
    users_location.loc[location_idx,'location_country'] = row.country

users_location.fillna('unknown',inplace=True)
users_location['location_country'] = users_location['location_country'].str.replace('n/a','unknown')
users_location['location_city'] = users_location['location_city'].str.replace('n/a','unknown')
users_location['location_state'] = users_location['location_state'].str.replace('n/a','unknown')

# %% [markdown]
# sklearn의 LabelEncoder을 통해 라벨 인코딩하여 사용하였습니다.

# %%
users_df = users_location.copy()
users_df['uid'] = users_df['user_id'].map(user2idx)

# %% [markdown]
# 아래와 같이 신규 user가 존재함을 확인할 수도 있습니다.

# %%
users_df.isnull().sum()
# Out:
# user_id               0
# age                   0
# location_country      0
# location_state        0
# location_city         0
# uid                 238
# dtype: int64

# %%
u_label = ['location_country', 'location_state', 'location_city']
u_encoder = dict()
for l in u_label:
    u_encoder[l] = LabelEncoder()
    u_encoder[l].fit(users_df[l])
    users_df[l] = u_encoder[l].transform(users_df[l])

# %% [markdown]
# 연속형 변수인 age에 대해 연령대별 카테고리화해 줍니다.

# %%
users_df['age'] = users_df['age'].map(lambda x:x//10 if type(x)!=str else -1)

# %%
users_df.head()
# Out:
#    user_id  age  location_country  location_state  location_city     uid
# 0        8 -1.0                19             355           4111     0.0
# 1    11400  4.0                19             355           3029   536.0
# 2    11676 -1.0               113             497           4193   549.0
# 3    67544  3.0                19             355           4130  3469.0
# 4    85526  3.0                19              75           4251  4395.0

# %% [markdown]
# ### Item
# 마찬가지로 item Feature 도 라벨인코딩해 줍니다.

# %% [markdown]
# 먼저, isbn을 iid로 바꾸어 줍니다.

# %%
books_df = books.copy()
books_df['iid'] = books_df['isbn'].map(book2idx)

# %% [markdown]
# 이어, 정규 표현식을 통해 카테고리를 보다 정제하여 주겠습니다.

# %%
books_df['category'] = books_df['category'].apply(lambda x: re.sub('[\W_]+',' ',str(x)).strip())

# %% [markdown]
# 결측치 처리 시, -1로 대체하였기 때문에 label encoding의 작동을 원활히 하기 위해 데이터의 type을 일치시켜 주었습니다.

# %%
books_df['category'] = books_df['category'].astype(str)
books_df['language'] = books_df['language'].astype(str)

# %% [markdown]
# item에 대한 정보는 제목, 작가명, 출판사 등 다양한 정보가 있지만 간결성을 위해 year_of_publication	, language, category를 제외하고 drop합니다.

# %%
i_label = ['category', 'language']
i_encoder = dict()
for l in i_label:
    i_encoder[l] = LabelEncoder()
    i_encoder[l].fit(books_df[l])
    books_df[l] = i_encoder[l].transform(books_df[l])

# %% [markdown]
# context aware recommendation을 위해, 각각의 데이터 프레임을 iid, uid를 기준으로 merge해 줍니다.

# %%
train_context = train_df.merge(users_df, on='uid', how='left').merge(books_df, on='iid', how='left')
test_context = test_df.merge(users_df, on='uid', how='left').merge(books_df, on='iid', how='left')

# %%
train_context.isna().sum()
# Out:
# uid                    0
# iid                    0
# ratings                0
# user_id                0
# age                    0
# location_country       0
# location_state         0
# location_city          0
# isbn                   0
# book_title             0
# book_author            0
# year_of_publication    0
# publisher              0
# img_url                0
# language               0
# category               0
# img_path               0
# summary                0
# dtype: int64

# %% [markdown]
# train/test set을 분할합니다.
# 추가적으로 다른 모델과 결과 공유할 때 같은 uid, iid 임을 확인하기 위해 rating_train/test 를 저장합니다.

# %%
X_train = train_context.drop(['user_id', 'isbn', 'iid','uid', 'ratings'], axis=1)
y_train = train_context['ratings']
rating_train = train_context[['uid','iid','ratings']] 

X_test = test_context.drop(['user_id', 'isbn', 'iid','uid', 'ratings'], axis=1)
y_test = test_context['ratings']
rating_test = test_context[['uid','iid','ratings']]

# %% [markdown]
# 불필요한 feature를 제거하여 줍니다.

# %%
drop_lst = ['book_title','book_author','publisher','img_url','img_path','summary']

X_train.drop(drop_lst,axis=1,inplace=True)
X_test.drop(drop_lst,axis=1,inplace=True)

# %% [markdown]
# 마찬가지로 RAM 관리를 위해 사용하지 않는 데이터 프레임을 삭제할 수도 있습니다. magic command 를 사용하여 현행 정의해놓은 변수 목록을 확인한 후, 삭제 가능합니다. (*길이상 주석처리하여 놓았습니다.)

# %%
#  %whos

# %%
# del ratings, users, books, books_df, users_df, users_location, city_tab

# %% [markdown]
# 우리는 대회에서 사용하는 평가 지표 RMSE를 동일하게 사용하여, 모델을 평가합니다. 이를 위해 rmse를 측정하는 함수를 제작합니다. 이 때, 평가결과를 보다 간결하게 보여주기 위해, 0점 미만의 평점은 0점, 10점 이상의 평점은 10점으로 처리하였습니다.

# %%
def modify_range(rating):
  if rating < 0:
    return 0
  elif rating > 10:
    return 10
  else:
    return rating

# %%
def rmse(real, predict):
  pred = list(map(modify_range, predict))  
  pred = np.array(pred)
  return np.sqrt(np.mean((real-pred) ** 2))

# %%
def matrix_rmse(real_mat, predict_mat, test_ind=test_idx):
  cost = 0

  for i, ind in enumerate(test_ind):
    pred = predict_mat[ind]
    real = real_mat[ind]
    cost += pow(real - modify_range(pred), 2)
  return np.sqrt(cost/ len(test_ind))

# %% [markdown]
# # [5] 단일 모델 확보

# %% [markdown]
# 하이브리드 접근법 파트에서 바로 사용할 수 있도록 모델을 미리 만들어 놓겠습니다.
#
# 지금까지 3,4, 5강에서 배웠던 방법론들을 이용하여 보겠습니다.

# %% [markdown]
# ## SVD
# 5강에서 배웠던 surprise 라이브러리를 사용하여 모델을 만들어 줍니다.

# %%
reader = Reader(rating_scale=(1, 10))
train_data = Dataset.load_from_df(train_df[['uid', 'iid', 'ratings']], reader)
test_data = Dataset.load_from_df(test_df[['uid', 'iid', 'ratings']], reader)

# %%
fold = DatasetAutoFolds(df = train_df[['uid', 'iid', 'ratings']], reader = reader)
trainset = fold.build_full_trainset()

# %% [markdown]
# 모든 미지수를 추정하기 위해 다음과 같은 정규화 제곱 오차를 최소화합니다.
#
# $$
# \hat{r}_{ui} = \mu + b_u + b_i + q_i^Tp_u
# $$
#
# 최소화는 매우 간단한 확률적 경사 하강법으로 수행됩니다.
# $$e_{ui} = r_{ui} - \hat{r}_{ui}$$
# 일 때,
# $$
# \begin{split}b_u &\leftarrow b_u &+ \gamma (e_{ui} - \lambda b_u)\\
# b_i &\leftarrow b_i &+ \gamma (e_{ui} - \lambda b_i)\\
# p_u &\leftarrow p_u &+ \gamma (e_{ui} \cdot q_i - \lambda p_u)\\
# q_i &\leftarrow q_i &+ \gamma (e_{ui} \cdot p_u - \lambda q_i)\end{split}
# $$
# 이 단계는 trainset의 모든 rating에 대해 n_epochs만큼 반복 수행됩니다.

# %%
params = {'n_factors':100,
          'n_epochs':20,
          'lr_all':0.005,
          'reg_all':0.02}

svd = SVD(**params,random_state=42)
svd.fit(trainset)

# %% [markdown]
# 예측을 위해 test 메소드에서 사용할 (u,i,r) 형식의 리스트를 생성합니다.

# %%
uir_tuple = list(zip(test_df['uid'], test_df['iid'],test_df['ratings']))

# %%
svd_test = svd.test(uir_tuple)

# %%
svd_pred = list(map(lambda x:round(x.est), svd_test))
pd.Series(svd_pred).value_counts()
# Out:
# 6     12797
# 7      8705
# 5      5935
# 8      2789
# 4      1401
# 9       789
# 3       253
# 10      207
# 2        52
# 1        18
# dtype: int64

# %% [markdown]
# 모델의 성능을 파악하기 위한 score dictionary를 생성하고, SVD 모델의 RMSE를 기록합니다.
# 파라미터 또한 기록하여 줍니다.

# %%
param = {}
param['svd'] = params

# %%
score = {}
score['svd'] = rmse(y_test, svd_pred)

# %%
pred = {}
pred['svd'] = svd_pred

# %%
rmse_v = score['svd']
print(f"RMSE of svd : {round(rmse_v,4)}")
# Out:
# RMSE of svd : 3.2394

# %% [markdown]
# ## Co-clustering
# 사용자와 아이템에 각각 $C_
# u$,$C_i$,$C_ui$ 클러스터가 부여되고, 이에 대한 평균 평점에서부터 평점을 계산합니다.
#
#
# $$
# \hat{r}_{ui} = \overline{C_{ui}} + (\mu_u - \overline{C_u}) + (\mu_i- \overline{C_i})
# $$

# %% [markdown]
# 파라미터를 설정하고, 모델을 학습시킵니다.

# %%
params = {'n_cltr_u':10, 'n_cltr_i':10, 'n_epochs':20}
param['coclu'] = params

# %%
coclu = CoClustering(**params, random_state=42, verbose=True)
coclu.fit(trainset)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19

# %% [markdown]
# test 메소드를 통해 user-item 평점을 예측합니다.

# %%
coclu_test = coclu.test(uir_tuple)

# %% [markdown]
# 평점 데이터 이므로, round를 통해 정수로 변환해 주었습니다. (*round 처리와 같은 변환은 선택사항입니다.)

# %%
coclu_pred = list(map(lambda x:round(x.est), coclu_test))
pd.Series(coclu_pred).value_counts()
# Out:
# 6     5910
# 7     5722
# 8     4739
# 5     3635
# 9     3243
# 10    2978
# 4     2436
# 3     1615
# 1     1458
# 2     1210
# dtype: int64

# %%
pred['coclu'] = coclu_pred

# %% [markdown]
# 기정의한 rmse 함수를 통해 모델의 성능을 평가합니다.

# %%
score['coclu'] = rmse(y_test, coclu_pred)

# %%
rmse_v = score['coclu']
print(f"RMSE of coclustering : {round(rmse_v,4)}")
# Out:
# RMSE of coclustering : 3.7928

# %% [markdown]
# ## LGBM

# %% [markdown]
# #### LGBM Classifier

# %% [markdown]
# 마찬가지로 LGBM 모델을 사용하여 모델을 만들어 줍니다.
# 이 때, params는 다음과 같이 설정하였습니다.

# %%
params = {'objective':'rmse',
  'boosting_type':'gbdt',
  'lambda': 0.1,
 'learning_rate': 0.03,
 'max_depth': 34,
 'num_leaves': 34,
 'n_epochs': 18}
param['lgbm'] = params

# %%
lgbm_cl = LGBMClassifier(**params ,random_state=42)
lgbm_cl.fit(X_train.select_dtypes(exclude='object'), y_train)
# Out:
# LGBMClassifier(lambda=0.1, learning_rate=0.03, max_depth=34, n_epochs=18,
#                num_leaves=34, objective='rmse', random_state=42)

# %% [markdown]
# 학습된 모델으로 예측을 수행합니다.

# %%
lgbm_pred_cl = lgbm_cl.predict(X_test.select_dtypes(exclude='object'))

# %%
pd.Series(lgbm_pred_cl).value_counts()
# Out:
# 1     28047
# 10     2383
# 8      1547
# 5       551
# 9       308
# 7        99
# 4         7
# 6         3
# 3         1
# dtype: int64

# %%
score['lgbm_cl'] = rmse(y_test,lgbm_pred_cl)
score['lgbm_cl']
# Out:
# 5.755384093460229

# %%
pred['lgbm_cl'] = lgbm_pred_cl

# %%
rmse_v = score['lgbm_cl']
print(f"RMSE of lgbm_classifier : {round(rmse_v,4)}")
# Out:
# RMSE of lgbm_classifier : 5.7554

# %% [markdown]
# #### LGBM Regressor

# %% [markdown]
# LGMB 모델을 사용하여 모델을 만들어 줍니다.
# 마찬가지로 예측을 진행합니다.

# %%
lgbm_r = LGBMRegressor(**params ,random_state=42)
lgbm_r.fit(X_train.select_dtypes(exclude='object'), y_train)
lgbm_pred_r = lgbm_r.predict(X_test.select_dtypes(exclude='object'))

# %%
score['lgbm_r'] = rmse(y_test,lgbm_pred_r)

# %% [markdown]
# 앙상블을 위해 생성한 pred dictionary에 예측 결과값을 추가합니다.

# %%
pred['lgbm_r'] = lgbm_pred_r

# %%
sns.distplot(pd.Series(lgbm_pred_r))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
pd.Series(lgbm_pred_r).map(round).value_counts()
# Out:
# 6    28448
# 7     4171
# 5      183
# 8      107
# 4       37
# dtype: int64

# %%
rmse_v = score['lgbm_r']
print(f"RMSE of lgbm_Regressor : {round(rmse_v,4)}")
# Out:
# RMSE of lgbm_Regressor : 3.2005

# %% [markdown]
# ## Catboost

# %% [markdown]
# #### Catboost Classifier

# %%
params = {}
params['iterations'] = 100
params['learning_rate']=0.1
params['depth']=8

# %%
param['catboost'] = params

# %%
catboost_cl = CatBoostClassifier(**params, verbose=True, random_state=42)
catboost_cl.fit(X_train.select_dtypes(exclude='object'), y_train, early_stopping_rounds=100)
catboost_pred_cl = catboost_cl.predict(X_test.select_dtypes(exclude='object'))
# Out:
# 0:	learn: 2.2480146	total: 233ms	remaining: 23.1s
# 1:	learn: 2.2028802	total: 383ms	remaining: 18.8s
# 2:	learn: 2.1663151	total: 531ms	remaining: 17.2s
# 3:	learn: 2.1356157	total: 682ms	remaining: 16.4s
# 4:	learn: 2.1095708	total: 827ms	remaining: 15.7s
# 5:	learn: 2.0866841	total: 972ms	remaining: 15.2s
# 6:	learn: 2.0673511	total: 1.16s	remaining: 15.4s
# 7:	learn: 2.0511767	total: 1.36s	remaining: 15.7s
# 8:	learn: 2.0370196	total: 1.56s	remaining: 15.8s
# 9:	learn: 2.0247494	total: 1.76s	remaining: 15.8s
# 10:	learn: 2.0140332	total: 1.95s	remaining: 15.8s
# 11:	learn: 2.0046308	total: 2.15s	remaining: 15.8s
# 12:	learn: 1.9970205	total: 2.22s	remaining: 14.9s
# 13:	learn: 1.9899689	total: 2.43s	remaining: 14.9s
# 14:	learn: 1.9840429	total: 2.62s	remaining: 14.9s
# 15:	learn: 1.9775296	total: 2.82s	remaining: 14.8s
# 16:	learn: 1.9724997	total: 3s	remaining: 14.7s
# 17:	learn: 1.9680445	total: 3.19s	remaining: 14.5s
# 18:	learn: 1.9639084	total: 3.38s	remaining: 14.4s
# 19:	learn: 1.9594673	total: 3.53s	remaining: 14.1s
# 20:	learn: 1.9569573	total: 3.58s	remaining: 13.5s
# 21:	learn: 1.9542745	total: 3.72s	remaining: 13.2s
# 22:	learn: 1.9517791	total: 3.88s	remaining: 13s
# 23:	learn: 1.9498836	total: 4.02s	remaining: 12.7s
# 24:	learn: 1.9477614	total: 4.17s	remaining: 12.5s
# 25:	learn: 1.9461298	total: 4.32s	remaining: 12.3s
# 26:	learn: 1.9444984	total: 4.46s	remaining: 12.1s
# 27:	learn: 1.9427693	total: 4.61s	remaining: 11.9s
# 28:	learn: 1.9413611	total: 4.76s	remaining: 11.6s
# 29:	learn: 1.9402130	total: 4.9s	remaining: 11.4s
# 30:	learn: 1.9383177	total: 5.04s	remaining: 11.2s
# 31:	learn: 1.9367277	total: 5.18s	remaining: 11s
# 32:	learn: 1.9355642	total: 5.33s	remaining: 10.8s
# 33:	learn: 1.9344084	total: 5.48s	remaining: 10.6s
# 34:	learn: 1.9337138	total: 5.63s	remaining: 10.4s
# 35:	learn: 1.9326644	total: 5.77s	remaining: 10.3s
# 36:	learn: 1.9317642	total: 5.92s	remaining: 10.1s
# 37:	learn: 1.9308019	total: 6.06s	remaining: 9.89s
# 38:	learn: 1.9300842	total: 6.21s	remaining: 9.71s
# 39:	learn: 1.9296146	total: 6.35s	remaining: 9.53s
# 40:	learn: 1.9286901	total: 6.5s	remaining: 9.35s
# 41:	learn: 1.9279552	total: 6.66s	remaining: 9.19s
# 42:	learn: 1.9273272	total: 6.8s	remaining: 9.01s
# 43:	learn: 1.9267010	total: 6.95s	remaining: 8.85s
# 44:	learn: 1.9260787	total: 7.09s	remaining: 8.67s
# 45:	learn: 1.9254381	total: 7.24s	remaining: 8.5s
# 46:	learn: 1.9248325	total: 7.38s	remaining: 8.32s
# 47:	learn: 1.9245005	total: 7.52s	remaining: 8.15s
# 48:	learn: 1.9239673	total: 7.68s	remaining: 7.99s
# 49:	learn: 1.9232635	total: 7.83s	remaining: 7.83s
# 50:	learn: 1.9223142	total: 7.98s	remaining: 7.67s
# 51:	learn: 1.9217783	total: 8.13s	remaining: 7.5s
# 52:	learn: 1.9211851	total: 8.27s	remaining: 7.33s
# 53:	learn: 1.9208510	total: 8.41s	remaining: 7.17s
# 54:	learn: 1.9203687	total: 8.56s	remaining: 7s
# 55:	learn: 1.9195958	total: 8.71s	remaining: 6.84s
# 56:	learn: 1.9193040	total: 8.86s	remaining: 6.68s
# 57:	learn: 1.9190690	total: 8.99s	remaining: 6.51s
# 58:	learn: 1.9188153	total: 9.14s	remaining: 6.35s
# 59:	learn: 1.9183317	total: 9.28s	remaining: 6.19s
# 60:	learn: 1.9177667	total: 9.43s	remaining: 6.03s
# 61:	learn: 1.9174449	total: 9.57s	remaining: 5.87s
# 62:	learn: 1.9169228	total: 9.72s	remaining: 5.71s
# 63:	learn: 1.9164975	total: 9.86s	remaining: 5.55s
# 64:	learn: 1.9159903	total: 10s	remaining: 5.39s
# 65:	learn: 1.9155472	total: 10.2s	remaining: 5.24s
# 66:	learn: 1.9154163	total: 10.3s	remaining: 5.08s
# 67:	learn: 1.9149142	total: 10.4s	remaining: 4.92s
# 68:	learn: 1.9145893	total: 10.6s	remaining: 4.76s
# 69:	learn: 1.9142829	total: 10.7s	remaining: 4.6s
# 70:	learn: 1.9138282	total: 10.9s	remaining: 4.45s
# 71:	learn: 1.9129978	total: 11s	remaining: 4.29s
# 72:	learn: 1.9125698	total: 11.2s	remaining: 4.13s
# 73:	learn: 1.9121261	total: 11.3s	remaining: 3.98s
# 74:	learn: 1.9118413	total: 11.5s	remaining: 3.82s
# 75:	learn: 1.9115134	total: 11.6s	remaining: 3.67s
# 76:	learn: 1.9111308	total: 11.8s	remaining: 3.52s
# 77:	learn: 1.9108316	total: 11.9s	remaining: 3.36s
# 78:	learn: 1.9103612	total: 12.1s	remaining: 3.21s
# 79:	learn: 1.9100060	total: 12.2s	remaining: 3.05s
# 80:	learn: 1.9094959	total: 12.4s	remaining: 2.9s
# 81:	learn: 1.9088358	total: 12.5s	remaining: 2.74s
# 82:	learn: 1.9083706	total: 12.6s	remaining: 2.59s
# 83:	learn: 1.9079334	total: 12.8s	remaining: 2.44s
# 84:	learn: 1.9077630	total: 12.9s	remaining: 2.28s
# 85:	learn: 1.9075648	total: 13.1s	remaining: 2.13s
# 86:	learn: 1.9072715	total: 13.3s	remaining: 1.98s
# 87:	learn: 1.9069484	total: 13.5s	remaining: 1.84s
# 88:	learn: 1.9067772	total: 13.8s	remaining: 1.7s
# 89:	learn: 1.9061195	total: 14.1s	remaining: 1.56s
# 90:	learn: 1.9056320	total: 14.4s	remaining: 1.42s
# 91:	learn: 1.9051254	total: 14.7s	remaining: 1.28s
# 92:	learn: 1.9049083	total: 15.1s	remaining: 1.13s
# 93:	learn: 1.9044451	total: 15.3s	remaining: 977ms
# 94:	learn: 1.9038550	total: 15.6s	remaining: 821ms
# 95:	learn: 1.9035207	total: 15.9s	remaining: 661ms
# 96:	learn: 1.9031438	total: 16.1s	remaining: 498ms
# 97:	learn: 1.9027428	total: 16.3s	remaining: 333ms
# 98:	learn: 1.9024539	total: 16.6s	remaining: 167ms
# 99:	learn: 1.9022847	total: 16.8s	remaining: 0us

# %%
score['catboost_cl'] = rmse(y_test,catboost_pred_cl.squeeze(1))

# %%
pred['catboost_cl'] = catboost_pred_cl.squeeze(1)

# %%
rmse_v = score['catboost_cl']
print(f"RMSE of Catboost Classifier : {round(rmse_v,4)}")
# Out:
# RMSE of Catboost Classifier : 5.6917

# %% [markdown]
# #### Catboost Regressor

# %%
catboost_r = CatBoostRegressor(**params, verbose=True, random_state=42)
catboost_r.fit(X_train.select_dtypes(exclude='object'), y_train, early_stopping_rounds=100)
catboost_pred_r = catboost_r.predict(X_test.select_dtypes(exclude='object'))
# Out:
# 0:	learn: 3.2381367	total: 25.2ms	remaining: 2.5s
# 1:	learn: 3.2359755	total: 50.6ms	remaining: 2.48s
# 2:	learn: 3.2341445	total: 94.1ms	remaining: 3.04s
# 3:	learn: 3.2329366	total: 119ms	remaining: 2.87s
# 4:	learn: 3.2317988	total: 141ms	remaining: 2.67s
# 5:	learn: 3.2303401	total: 157ms	remaining: 2.46s
# 6:	learn: 3.2293368	total: 174ms	remaining: 2.31s
# 7:	learn: 3.2283808	total: 196ms	remaining: 2.25s
# 8:	learn: 3.2275820	total: 215ms	remaining: 2.17s
# 9:	learn: 3.2267838	total: 239ms	remaining: 2.15s
# 10:	learn: 3.2258680	total: 255ms	remaining: 2.06s
# 11:	learn: 3.2253915	total: 272ms	remaining: 1.99s
# 12:	learn: 3.2247664	total: 288ms	remaining: 1.93s
# 13:	learn: 3.2241535	total: 305ms	remaining: 1.87s
# 14:	learn: 3.2233312	total: 330ms	remaining: 1.87s
# 15:	learn: 3.2227647	total: 363ms	remaining: 1.91s
# 16:	learn: 3.2222270	total: 391ms	remaining: 1.91s
# 17:	learn: 3.2218278	total: 424ms	remaining: 1.93s
# 18:	learn: 3.2210107	total: 453ms	remaining: 1.93s
# 19:	learn: 3.2203266	total: 470ms	remaining: 1.88s
# 20:	learn: 3.2198526	total: 487ms	remaining: 1.83s
# 21:	learn: 3.2195904	total: 508ms	remaining: 1.8s
# 22:	learn: 3.2190011	total: 528ms	remaining: 1.77s
# 23:	learn: 3.2184646	total: 557ms	remaining: 1.76s
# 24:	learn: 3.2181982	total: 579ms	remaining: 1.74s
# 25:	learn: 3.2176194	total: 596ms	remaining: 1.7s
# 26:	learn: 3.2172834	total: 613ms	remaining: 1.66s
# 27:	learn: 3.2166681	total: 635ms	remaining: 1.63s
# 28:	learn: 3.2162604	total: 657ms	remaining: 1.61s
# 29:	learn: 3.2160384	total: 727ms	remaining: 1.7s
# 30:	learn: 3.2157518	total: 773ms	remaining: 1.72s
# 31:	learn: 3.2151691	total: 795ms	remaining: 1.69s
# 32:	learn: 3.2148033	total: 812ms	remaining: 1.65s
# 33:	learn: 3.2144231	total: 829ms	remaining: 1.61s
# 34:	learn: 3.2138919	total: 851ms	remaining: 1.58s
# 35:	learn: 3.2136878	total: 866ms	remaining: 1.54s
# 36:	learn: 3.2134884	total: 882ms	remaining: 1.5s
# 37:	learn: 3.2133415	total: 899ms	remaining: 1.47s
# 38:	learn: 3.2130653	total: 915ms	remaining: 1.43s
# 39:	learn: 3.2126428	total: 936ms	remaining: 1.4s
# 40:	learn: 3.2121126	total: 954ms	remaining: 1.37s
# 41:	learn: 3.2117602	total: 977ms	remaining: 1.35s
# 42:	learn: 3.2115637	total: 992ms	remaining: 1.31s
# 43:	learn: 3.2112119	total: 1.01s	remaining: 1.29s
# 44:	learn: 3.2107271	total: 1.03s	remaining: 1.26s
# 45:	learn: 3.2102154	total: 1.05s	remaining: 1.23s
# 46:	learn: 3.2099910	total: 1.08s	remaining: 1.22s
# 47:	learn: 3.2097303	total: 1.1s	remaining: 1.2s
# 48:	learn: 3.2092426	total: 1.13s	remaining: 1.18s
# 49:	learn: 3.2089896	total: 1.16s	remaining: 1.16s
# 50:	learn: 3.2084650	total: 1.2s	remaining: 1.15s
# 51:	learn: 3.2083299	total: 1.22s	remaining: 1.12s
# 52:	learn: 3.2078565	total: 1.24s	remaining: 1.09s
# 53:	learn: 3.2075455	total: 1.25s	remaining: 1.07s
# 54:	learn: 3.2074207	total: 1.27s	remaining: 1.04s
# 55:	learn: 3.2072106	total: 1.29s	remaining: 1.01s
# 56:	learn: 3.2068761	total: 1.3s	remaining: 985ms
# 57:	learn: 3.2065230	total: 1.33s	remaining: 962ms
# 58:	learn: 3.2061403	total: 1.35s	remaining: 936ms
# 59:	learn: 3.2059029	total: 1.36s	remaining: 911ms
# 60:	learn: 3.2057149	total: 1.38s	remaining: 885ms
# 61:	learn: 3.2055671	total: 1.4s	remaining: 860ms
# 62:	learn: 3.2053478	total: 1.42s	remaining: 834ms
# 63:	learn: 3.2050375	total: 1.44s	remaining: 810ms
# 64:	learn: 3.2049227	total: 1.46s	remaining: 788ms
# 65:	learn: 3.2044214	total: 1.49s	remaining: 766ms
# 66:	learn: 3.2042401	total: 1.5s	remaining: 741ms
# 67:	learn: 3.2039419	total: 1.53s	remaining: 718ms
# 68:	learn: 3.2037748	total: 1.54s	remaining: 693ms
# 69:	learn: 3.2034228	total: 1.57s	remaining: 673ms
# 70:	learn: 3.2031858	total: 1.59s	remaining: 649ms
# 71:	learn: 3.2030014	total: 1.61s	remaining: 626ms
# 72:	learn: 3.2029116	total: 1.64s	remaining: 605ms
# 73:	learn: 3.2024512	total: 1.66s	remaining: 583ms
# 74:	learn: 3.2022750	total: 1.68s	remaining: 560ms
# 75:	learn: 3.2018319	total: 1.7s	remaining: 536ms
# 76:	learn: 3.2015192	total: 1.72s	remaining: 512ms
# 77:	learn: 3.2013956	total: 1.73s	remaining: 488ms
# 78:	learn: 3.2012527	total: 1.75s	remaining: 467ms
# 79:	learn: 3.2008855	total: 1.78s	remaining: 444ms
# 80:	learn: 3.2006086	total: 1.8s	remaining: 422ms
# 81:	learn: 3.2003530	total: 1.82s	remaining: 400ms
# 82:	learn: 3.2002095	total: 1.84s	remaining: 376ms
# 83:	learn: 3.2001026	total: 1.86s	remaining: 354ms
# 84:	learn: 3.1998284	total: 1.9s	remaining: 335ms
# 85:	learn: 3.1994883	total: 1.93s	remaining: 314ms
# 86:	learn: 3.1993214	total: 1.95s	remaining: 291ms
# 87:	learn: 3.1991843	total: 1.97s	remaining: 269ms
# 88:	learn: 3.1988201	total: 2s	remaining: 247ms
# 89:	learn: 3.1986300	total: 2.04s	remaining: 226ms
# 90:	learn: 3.1981803	total: 2.06s	remaining: 204ms
# 91:	learn: 3.1979690	total: 2.08s	remaining: 181ms
# 92:	learn: 3.1976885	total: 2.1s	remaining: 158ms
# 93:	learn: 3.1975373	total: 2.11s	remaining: 135ms
# 94:	learn: 3.1974066	total: 2.13s	remaining: 112ms
# 95:	learn: 3.1972134	total: 2.16s	remaining: 89.9ms
# 96:	learn: 3.1969069	total: 2.18s	remaining: 67.5ms
# 97:	learn: 3.1967786	total: 2.22s	remaining: 45.3ms
# 98:	learn: 3.1965203	total: 2.23s	remaining: 22.6ms
# 99:	learn: 3.1961594	total: 2.28s	remaining: 0us

# %%
score['catboost_r'] = rmse(y_test,catboost_pred_r)

# %%
pred['catboost_r'] = catboost_pred_r

# %%
rmse_v = score['catboost_r']
print(f"RMSE of Catboost Regressor : {round(rmse_v,4)}")
# Out:
# RMSE of Catboost Regressor : 3.2015

# %% [markdown]
# # [6] 하이브리드 접근법을 이용한 성능 개선

# %% [markdown]
# 현재까지 하이브리드 기법을 이용하지 않은 성능은 다음과 같습니다.

# %%
score
# Out:
# {'svd': 3.239372605189222,
#  'coclu': 3.7927994286035283,
#  'lgbm_cl': 5.755384093460229,
#  'lgbm_r': 3.2005427265045934,
#  'catboost_cl': 5.691741438025897,
#  'catboost_r': 3.20149622525757}

# %% [markdown]
# ## Weighted
#
# 먼저 각 결과값에 가중치를 주어, 결과를 앙상블하는 기법인 weighted Approach에 대해 알아봅시다.

# %% [markdown]
# ### Simple Weight : 직접 지정
#
# 먼저, 직접 지정하는 방법입니다.

# %%
# 기본 Weight
def simple_weighted(output_list: list, weight: list):
    pred = []
    for arr in output_list:
        pred.append(arr)

    pred_arr = np.append([pred[0]], [pred[1]], axis=0)
    for i in range(2, len(pred)):
        pred_arr = np.append(pred_arr, [pred[i]], axis=0)
    
    result = np.dot(pred_arr.T, np.array(weight))
    return result

# %% [markdown]
# simple_weighted 함수를 통해 각 모델에서부터 도출된 예측값 list를 입력해주고, 이에 대한 가중치를 지정해 줍니다.

# %%
weighted_pred = simple_weighted([svd_pred,lgbm_pred_r,catboost_pred_r], weight=[0.5, 0.2, 0.3])

# %% [markdown]
# 기존 모델에 비해 성능이 조금 향상됨을 확인할 수 있습니다.

# %%
rmse_v = rmse(y_test, weighted_pred)
print(f"RMSE of Simple Weighted : {round(rmse_v,4)}")
# Out:
# RMSE of Simple Weighted : 3.1727

# %% [markdown]
# ### Optimal Weight : 가중치 탐색

# %% [markdown]
# 아래 코드를 통해 최적의 weight를 찾을 수도 있습니다.
# 먼저 Weight를 줄 모델을 선정하여 봅니다.

# %% [markdown]
# 아래 함수는 단일 모델의 RMSE 성능이 threshold 이하인 경우, 해당하는 모델만을 선택하기 위해 제작된 함수입니다.

# %%
def find_suitable_model(score:dict,threshold:float)->list:
    suitable_models = [k for k,v in score.items() if v<threshold]
    return suitable_models

# %% [markdown]
# 활용할 모델을 선택하였습니다.

# %%
threshold = 3.4
suitable_models = find_suitable_model(score,threshold)
print(f"RMSE {threshold} 이하 모델 활용 : {suitable_models}")
# Out:
# RMSE 3.4 이하 모델 활용 : ['svd', 'lgbm_r', 'catboost_r']

# %%
output_list = [pred[m] for m in suitable_models]

# %% [markdown]
# 이를 random_weight 를 통해 optimal_weighted를 찾아보겠습니다.

# %%
def optimal_weighted(output_list: list, n:int)->dict:
    record = {'rmse':10,'weight':[]}
    
    for _ in range(n):
        random_weight = np.random.dirichlet(np.ones(len(output_list)),size=1).squeeze()
        pred_weight_zip = zip(output_list,random_weight)
        pred_weight_list = [pred*np.array(weight) for pred, weight in pred_weight_zip]
        pred_result = np.sum(pred_weight_list, axis=0)
        rmse_v = rmse(y_test,pred_result)
        if rmse_v < record['rmse']:
            record['rmse'] = rmse_v
            record['weight'] = random_weight
    return record

# %% [markdown]
# 조금 더 향상된 결과를 확인할 수 있습니다.

# %%
opt_w = optimal_weighted(output_list=output_list,n=100)
opt_w
# Out:
# {'rmse': 3.170660569480184,
#  'weight': array([0.39376204, 0.16838073, 0.43785723])}

# %% [markdown]
# 위 코드에서 얻은 optimal한 weight을 가지고, 최적의 pred값을 얻어보겠습니다.

# %%
opt_weighted_pred = simple_weighted(output_list,
                                    weight=opt_w['weight'])

# %%
pred['opt_weight'] = opt_weighted_pred

# %%
rmse_v = rmse(y_test, opt_weighted_pred)
score['opt_weight'] = rmse_v
print(f"RMSE of Optimal Weighted : {round(rmse_v,4)}")
# Out:
# RMSE of Optimal Weighted : 3.1707

# %% [markdown]
# ## Feature Combine
#
# Feature Combine 방법을 이용하여, 타 모델에서 생성된 pred 값을 Input으로 사용합니다.
#
# item과 user의 feature를 사용하는 LGBM, Catboost에 추가하여 넘겨주도록 하겠습니다.

# %%
score
# Out:
# {'svd': 3.239372605189222,
#  'coclu': 3.7927994286035283,
#  'lgbm_cl': 5.755384093460229,
#  'lgbm_r': 3.2005427265045934,
#  'catboost_cl': 5.691741438025897,
#  'catboost_r': 3.20149622525757,
#  'opt_weight': 3.170660569480184}

# %% [markdown]
# 성능이 가장 좋지 않았던 lgbm_cl, catboost_cl 등의 classifier model
#  성능 향상을 확인해 보겠습니다.

# %%
train_uir_tuple = list(zip(train_df['uid'], train_df['iid'], train_df['ratings']))

# %%
X_train_combine = X_train.copy()
X_test_combine = X_test.copy()

# %% [markdown]
# ### Rating Feature 추가

# %% [markdown]
# 여기서는 user-item 사이 interaction 데이터를 이용한 SVD, Co-clustering 알고리즘에서 예측한 pred_rating 에 대한 정보를 넘겨주도록 하겠습니다.

# %%
X_train_combine['svd_rating'] = list(map(lambda x:round(x.est), svd.test(train_uir_tuple)))
X_test_combine['svd_rating'] = svd_pred

# %%
X_train_combine['coclu_rating'] = list(map(lambda x:round(x.est), coclu.test(train_uir_tuple)))
X_test_combine['coclu_rating'] = coclu_pred

# %%
combined_lgbm_cl = LGBMClassifier(**param['lgbm'] , random_state=42)
combined_lgbm_cl.fit(X_train_combine.select_dtypes(exclude='object'), y_train)
com_lgbm_pred = combined_lgbm_cl.predict(X_test_combine.select_dtypes(exclude='object'))

# %% [markdown]
# ### 성능 향상

# %% [markdown]
# svd 모델에서 파생된 rating pred를 추가한 경우, 같은 파라미터를 사용한 기존 모델보다 성능을 훨씬 향상됨을 확인할 수 있습니다.
#
# <!-- only SVD: 3.416 -->

# %%
pred['combined_lgbm_cl'] = com_lgbm_pred

# %%
rmse_v = rmse(y_test, com_lgbm_pred)
score['combined_lgbm_cl'] = rmse_v
print(f"RMSE of Combined LGBM Classifier : {round(rmse_v,4)}")
# Out:
# RMSE of Combined LGBM Classifier : 3.6398

# %%
improved = rmse_v - score['lgbm_cl']
print(f'feature combine improved RMSE {round(improved,4)}')
# Out:
# feature combine improved RMSE -2.1156

# %% [markdown]
# catboost의 case도 확인해 봅시다.

# %%
combined_catboost_cl = CatBoostClassifier(**param['catboost'], verbose=True, random_state=42)
combined_catboost_cl.fit(X_train_combine.select_dtypes(exclude='object'), y_train, early_stopping_rounds=100)
com_catboost_pred = combined_catboost_cl.predict(X_test_combine.select_dtypes(exclude='object'))
# Out:
# 0:	learn: 1.9336375	total: 174ms	remaining: 17.2s
# 1:	learn: 1.7451568	total: 343ms	remaining: 16.8s
# 2:	learn: 1.6109509	total: 518ms	remaining: 16.7s
# 3:	learn: 1.5089296	total: 682ms	remaining: 16.4s
# 4:	learn: 1.4276562	total: 847ms	remaining: 16.1s
# 5:	learn: 1.3638229	total: 1.01s	remaining: 15.9s
# 6:	learn: 1.3102555	total: 1.19s	remaining: 15.8s
# 7:	learn: 1.2651344	total: 1.36s	remaining: 15.7s
# 8:	learn: 1.2273203	total: 1.53s	remaining: 15.5s
# 9:	learn: 1.1936943	total: 1.71s	remaining: 15.3s
# 10:	learn: 1.1651922	total: 1.87s	remaining: 15.1s
# 11:	learn: 1.1409817	total: 2.04s	remaining: 15s
# 12:	learn: 1.1194652	total: 2.21s	remaining: 14.8s
# 13:	learn: 1.1006769	total: 2.38s	remaining: 14.6s
# 14:	learn: 1.0831496	total: 2.54s	remaining: 14.4s
# 15:	learn: 1.0676175	total: 2.7s	remaining: 14.2s
# 16:	learn: 1.0541292	total: 2.91s	remaining: 14.2s
# 17:	learn: 1.0422153	total: 3.13s	remaining: 14.3s
# 18:	learn: 1.0319425	total: 3.35s	remaining: 14.3s
# 19:	learn: 1.0224598	total: 3.57s	remaining: 14.3s
# 20:	learn: 1.0143922	total: 3.78s	remaining: 14.2s
# 21:	learn: 1.0072925	total: 4.01s	remaining: 14.2s
# 22:	learn: 0.9994714	total: 4.23s	remaining: 14.2s
# 23:	learn: 0.9947289	total: 4.45s	remaining: 14.1s
# 24:	learn: 0.9891334	total: 4.66s	remaining: 14s
# 25:	learn: 0.9844470	total: 4.88s	remaining: 13.9s
# 26:	learn: 0.9802044	total: 5.1s	remaining: 13.8s
# 27:	learn: 0.9764182	total: 5.28s	remaining: 13.6s
# 28:	learn: 0.9725831	total: 5.44s	remaining: 13.3s
# 29:	learn: 0.9688672	total: 5.61s	remaining: 13.1s
# 30:	learn: 0.9656096	total: 5.78s	remaining: 12.9s
# 31:	learn: 0.9626958	total: 5.95s	remaining: 12.6s
# 32:	learn: 0.9602429	total: 6.13s	remaining: 12.4s
# 33:	learn: 0.9580082	total: 6.29s	remaining: 12.2s
# 34:	learn: 0.9556946	total: 6.47s	remaining: 12s
# 35:	learn: 0.9539027	total: 6.64s	remaining: 11.8s
# 36:	learn: 0.9523581	total: 6.8s	remaining: 11.6s
# 37:	learn: 0.9501916	total: 6.96s	remaining: 11.4s
# 38:	learn: 0.9482359	total: 7.13s	remaining: 11.2s
# 39:	learn: 0.9470877	total: 7.29s	remaining: 10.9s
# 40:	learn: 0.9450943	total: 7.46s	remaining: 10.7s
# 41:	learn: 0.9442163	total: 7.63s	remaining: 10.5s
# 42:	learn: 0.9425679	total: 7.79s	remaining: 10.3s
# 43:	learn: 0.9413286	total: 7.95s	remaining: 10.1s
# 44:	learn: 0.9402141	total: 8.14s	remaining: 9.95s
# 45:	learn: 0.9396261	total: 8.31s	remaining: 9.75s
# 46:	learn: 0.9384405	total: 8.48s	remaining: 9.56s
# 47:	learn: 0.9375705	total: 8.65s	remaining: 9.37s
# 48:	learn: 0.9366372	total: 8.81s	remaining: 9.17s
# 49:	learn: 0.9357836	total: 8.97s	remaining: 8.97s
# 50:	learn: 0.9350450	total: 9.14s	remaining: 8.78s
# 51:	learn: 0.9344700	total: 9.3s	remaining: 8.59s
# 52:	learn: 0.9335974	total: 9.47s	remaining: 8.39s
# 53:	learn: 0.9327987	total: 9.63s	remaining: 8.21s
# 54:	learn: 0.9318511	total: 9.8s	remaining: 8.02s
# 55:	learn: 0.9308416	total: 9.96s	remaining: 7.83s
# 56:	learn: 0.9300732	total: 10.1s	remaining: 7.64s
# 57:	learn: 0.9294263	total: 10.3s	remaining: 7.46s
# 58:	learn: 0.9288805	total: 10.5s	remaining: 7.28s
# 59:	learn: 0.9280858	total: 10.6s	remaining: 7.09s
# 60:	learn: 0.9275428	total: 10.8s	remaining: 6.9s
# 61:	learn: 0.9271571	total: 11s	remaining: 6.71s
# 62:	learn: 0.9264857	total: 11.1s	remaining: 6.54s
# 63:	learn: 0.9260801	total: 11.3s	remaining: 6.35s
# 64:	learn: 0.9253313	total: 11.5s	remaining: 6.17s
# 65:	learn: 0.9244951	total: 11.6s	remaining: 5.99s
# 66:	learn: 0.9242582	total: 11.8s	remaining: 5.8s
# 67:	learn: 0.9237428	total: 11.9s	remaining: 5.62s
# 68:	learn: 0.9232918	total: 12.1s	remaining: 5.44s
# 69:	learn: 0.9229713	total: 12.3s	remaining: 5.27s
# 70:	learn: 0.9224930	total: 12.5s	remaining: 5.09s
# 71:	learn: 0.9220056	total: 12.6s	remaining: 4.91s
# 72:	learn: 0.9215788	total: 12.8s	remaining: 4.73s
# 73:	learn: 0.9209548	total: 13s	remaining: 4.55s
# 74:	learn: 0.9203454	total: 13.1s	remaining: 4.37s
# 75:	learn: 0.9195773	total: 13.3s	remaining: 4.19s
# 76:	learn: 0.9190505	total: 13.4s	remaining: 4.02s
# 77:	learn: 0.9184808	total: 13.6s	remaining: 3.84s
# 78:	learn: 0.9178974	total: 13.8s	remaining: 3.66s
# 79:	learn: 0.9174450	total: 13.9s	remaining: 3.49s
# 80:	learn: 0.9168792	total: 14.1s	remaining: 3.31s
# 81:	learn: 0.9162469	total: 14.3s	remaining: 3.13s
# 82:	learn: 0.9157831	total: 14.4s	remaining: 2.96s
# 83:	learn: 0.9154581	total: 14.6s	remaining: 2.78s
# 84:	learn: 0.9151023	total: 14.8s	remaining: 2.61s
# 85:	learn: 0.9144823	total: 14.9s	remaining: 2.43s
# 86:	learn: 0.9140374	total: 15.1s	remaining: 2.26s
# 87:	learn: 0.9137073	total: 15.3s	remaining: 2.09s
# 88:	learn: 0.9134430	total: 15.5s	remaining: 1.92s
# 89:	learn: 0.9129770	total: 15.7s	remaining: 1.75s
# 90:	learn: 0.9127317	total: 15.9s	remaining: 1.58s
# 91:	learn: 0.9122195	total: 16.2s	remaining: 1.41s
# 92:	learn: 0.9119190	total: 16.4s	remaining: 1.23s
# 93:	learn: 0.9116313	total: 16.6s	remaining: 1.06s
# 94:	learn: 0.9111565	total: 16.8s	remaining: 886ms
# 95:	learn: 0.9108264	total: 17s	remaining: 710ms
# 96:	learn: 0.9103182	total: 17.3s	remaining: 534ms
# 97:	learn: 0.9098837	total: 17.5s	remaining: 357ms
# 98:	learn: 0.9095306	total: 17.7s	remaining: 179ms
# 99:	learn: 0.9092002	total: 17.9s	remaining: 0us

# %%
pred['combined_catboost_cl'] = com_catboost_pred.squeeze(1)

# %%
rmse_v = rmse(y_test,com_catboost_pred.squeeze(1))
score['combined_catboost_cl'] = rmse_v
print(f"RMSE of Combined Catboost Classifier : {round(rmse_v,4)}")
# Out:
# RMSE of Combined Catboost Classifier : 3.6347

# %%
improved = rmse_v - score['catboost_cl']
print(f'Feature combine improved RMSE {round(improved,4)}')
# Out:
# Feature combine improved RMSE -2.057

# %% [markdown]
# ## Mixed
# 일반적인 Mixed 형식의 하이브리드 접근법은 Ranking 문제에서 주로 사용하는 방식입니다.
# 예를 들어, top k를 추천할 때 n개의 모델에서 나온 item을 각각 섞어 k개를 선정하는 것을 들 수 있습니다.
#
# prediction
# 을 목적으로 진행하는 이번 과제에서는 일반적인 mixed 형식은 어렵습니다.
# 이에 따라, 이번 미션에서는 케이스 별 모델에서 도출한 pred rating을 섞어 최종 결과로 사용하는 방식의 개량된 mixed approach에 대해 알아보겠습니다.

# %% [markdown]
# ### Case 분화

# %% [markdown]
# 예시를 위해 pulication이 2000년 미만인 경우(20세기)와 이후인 경우(21세기)를 분화하여, 각각 다른 모델을 섞어보도록 하겠습니다.

# %% [markdown]
# > train Set 케이스 분화

# %%
X_train_combine_21cent = X_train_combine[~(X_train_combine['year_of_publication'] < 2000)].copy().reset_index(drop=True)
X_train_combine_20cent = X_train_combine[X_train_combine['year_of_publication'] < 2000].copy().reset_index(drop=True)

# %%
y_train_21cent = y_train[~(X_train_combine['year_of_publication'] < 2000)].copy().reset_index(drop=True)
y_train_20cent = y_train[X_train_combine['year_of_publication'] < 2000].copy().reset_index(drop=True)

# %% [markdown]
# > test set 케이스 분화

# %%
X_test_combine_21cent = X_test_combine[~(X_test_combine['year_of_publication'] < 2000)].copy().reset_index(drop=True)
X_test_combine_20cent = X_test_combine[X_test_combine['year_of_publication'] < 2000].copy().reset_index(drop=True)

# %%
y_test_21cent = y_test[~(X_test_combine['year_of_publication'] < 2000)].copy().reset_index(drop=True)
y_test_20cent = y_test[X_test_combine['year_of_publication'] < 2000].copy().reset_index(drop=True)

# %% [markdown]
# ### Case 별 모델 학습

# %%
# 20세기
lgbm_20cent = LGBMClassifier(**param['lgbm'] , random_state=42)
lgbm_20cent.fit(X_train_combine_20cent.select_dtypes(exclude='object'), y_train_20cent)
lgbm_20cent_pred = lgbm_20cent.predict(X_test_combine_20cent.select_dtypes(exclude='object'))

# %%
# 21세기
catboost_21cent = CatBoostClassifier(**param['catboost'] , random_state=42)
catboost_21cent.fit(X_train_combine_21cent.select_dtypes(exclude='object'), y_train_21cent)
catboost_21cent_pred = catboost_21cent.predict(X_test_combine_21cent.select_dtypes(exclude='object'))
# Out:
# 0:	learn: 1.9586047	total: 51.3ms	remaining: 5.08s
# 1:	learn: 1.7652303	total: 110ms	remaining: 5.4s
# 2:	learn: 1.6379576	total: 159ms	remaining: 5.13s
# 3:	learn: 1.5378296	total: 208ms	remaining: 4.99s
# 4:	learn: 1.4557304	total: 257ms	remaining: 4.89s
# 5:	learn: 1.3917253	total: 304ms	remaining: 4.76s
# 6:	learn: 1.3390593	total: 352ms	remaining: 4.68s
# 7:	learn: 1.2917427	total: 399ms	remaining: 4.59s
# 8:	learn: 1.2521007	total: 445ms	remaining: 4.5s
# 9:	learn: 1.2180930	total: 492ms	remaining: 4.43s
# 10:	learn: 1.1897816	total: 551ms	remaining: 4.46s
# 11:	learn: 1.1627185	total: 597ms	remaining: 4.38s
# 12:	learn: 1.1410508	total: 645ms	remaining: 4.31s
# 13:	learn: 1.1209042	total: 701ms	remaining: 4.31s
# 14:	learn: 1.1045503	total: 752ms	remaining: 4.26s
# 15:	learn: 1.0885978	total: 802ms	remaining: 4.21s
# 16:	learn: 1.0756378	total: 855ms	remaining: 4.17s
# 17:	learn: 1.0638946	total: 901ms	remaining: 4.1s
# 18:	learn: 1.0527320	total: 953ms	remaining: 4.06s
# 19:	learn: 1.0437971	total: 1.01s	remaining: 4.02s
# 20:	learn: 1.0348236	total: 1.05s	remaining: 3.96s
# 21:	learn: 1.0284063	total: 1.1s	remaining: 3.9s
# 22:	learn: 1.0205729	total: 1.16s	remaining: 3.87s
# 23:	learn: 1.0136873	total: 1.22s	remaining: 3.86s
# 24:	learn: 1.0076065	total: 1.27s	remaining: 3.8s
# 25:	learn: 1.0033130	total: 1.32s	remaining: 3.75s
# 26:	learn: 0.9976151	total: 1.36s	remaining: 3.69s
# 27:	learn: 0.9932779	total: 1.41s	remaining: 3.63s
# 28:	learn: 0.9891480	total: 1.46s	remaining: 3.57s
# 29:	learn: 0.9858335	total: 1.51s	remaining: 3.52s
# 30:	learn: 0.9818630	total: 1.55s	remaining: 3.46s
# 31:	learn: 0.9784171	total: 1.6s	remaining: 3.4s
# 32:	learn: 0.9750833	total: 1.65s	remaining: 3.34s
# 33:	learn: 0.9721114	total: 1.69s	remaining: 3.29s
# 34:	learn: 0.9686130	total: 1.74s	remaining: 3.24s
# 35:	learn: 0.9657788	total: 1.79s	remaining: 3.19s
# 36:	learn: 0.9632987	total: 1.84s	remaining: 3.13s
# 37:	learn: 0.9611778	total: 1.89s	remaining: 3.08s
# 38:	learn: 0.9585035	total: 1.93s	remaining: 3.02s
# 39:	learn: 0.9565402	total: 1.98s	remaining: 2.97s
# 40:	learn: 0.9546474	total: 2.02s	remaining: 2.92s
# 41:	learn: 0.9525101	total: 2.08s	remaining: 2.87s
# 42:	learn: 0.9505392	total: 2.12s	remaining: 2.81s
# 43:	learn: 0.9486375	total: 2.18s	remaining: 2.78s
# 44:	learn: 0.9467599	total: 2.25s	remaining: 2.74s
# 45:	learn: 0.9458847	total: 2.3s	remaining: 2.69s
# 46:	learn: 0.9447867	total: 2.34s	remaining: 2.64s
# 47:	learn: 0.9429534	total: 2.39s	remaining: 2.59s
# 48:	learn: 0.9415226	total: 2.44s	remaining: 2.54s
# 49:	learn: 0.9400310	total: 2.48s	remaining: 2.48s
# 50:	learn: 0.9383508	total: 2.53s	remaining: 2.43s
# 51:	learn: 0.9373244	total: 2.58s	remaining: 2.38s
# 52:	learn: 0.9353624	total: 2.63s	remaining: 2.33s
# 53:	learn: 0.9343126	total: 2.68s	remaining: 2.28s
# 54:	learn: 0.9326233	total: 2.73s	remaining: 2.23s
# 55:	learn: 0.9318933	total: 2.79s	remaining: 2.19s
# 56:	learn: 0.9308689	total: 2.84s	remaining: 2.14s
# 57:	learn: 0.9294594	total: 2.88s	remaining: 2.09s
# 58:	learn: 0.9282718	total: 2.93s	remaining: 2.04s
# 59:	learn: 0.9268226	total: 2.98s	remaining: 1.99s
# 60:	learn: 0.9251638	total: 3.04s	remaining: 1.94s
# 61:	learn: 0.9242549	total: 3.08s	remaining: 1.89s
# 62:	learn: 0.9232913	total: 3.13s	remaining: 1.84s
# 63:	learn: 0.9225850	total: 3.18s	remaining: 1.79s
# 64:	learn: 0.9215260	total: 3.23s	remaining: 1.74s
# 65:	learn: 0.9208982	total: 3.29s	remaining: 1.7s
# 66:	learn: 0.9202048	total: 3.34s	remaining: 1.65s
# 67:	learn: 0.9196410	total: 3.39s	remaining: 1.6s
# 68:	learn: 0.9182462	total: 3.46s	remaining: 1.55s
# 69:	learn: 0.9169874	total: 3.52s	remaining: 1.51s
# 70:	learn: 0.9157844	total: 3.59s	remaining: 1.47s
# 71:	learn: 0.9145748	total: 3.65s	remaining: 1.42s
# 72:	learn: 0.9135249	total: 3.78s	remaining: 1.4s
# 73:	learn: 0.9127654	total: 3.96s	remaining: 1.39s
# 74:	learn: 0.9123509	total: 4.05s	remaining: 1.35s
# 75:	learn: 0.9110800	total: 4.11s	remaining: 1.3s
# 76:	learn: 0.9101455	total: 4.18s	remaining: 1.25s
# 77:	learn: 0.9090617	total: 4.25s	remaining: 1.2s
# 78:	learn: 0.9085057	total: 4.33s	remaining: 1.15s
# 79:	learn: 0.9073234	total: 4.39s	remaining: 1.1s
# 80:	learn: 0.9063557	total: 4.46s	remaining: 1.04s
# 81:	learn: 0.9052954	total: 4.53s	remaining: 995ms
# 82:	learn: 0.9040373	total: 4.72s	remaining: 967ms
# 83:	learn: 0.9028086	total: 4.88s	remaining: 931ms
# 84:	learn: 0.9016955	total: 4.96s	remaining: 875ms
# 85:	learn: 0.9009187	total: 5.02s	remaining: 818ms
# 86:	learn: 0.9001657	total: 5.09s	remaining: 760ms
# 87:	learn: 0.8990216	total: 5.16s	remaining: 704ms
# 88:	learn: 0.8980809	total: 5.22s	remaining: 646ms
# 89:	learn: 0.8975025	total: 5.3s	remaining: 589ms
# 90:	learn: 0.8963656	total: 5.37s	remaining: 531ms
# 91:	learn: 0.8958739	total: 5.43s	remaining: 472ms
# 92:	learn: 0.8952238	total: 5.55s	remaining: 418ms
# 93:	learn: 0.8942067	total: 5.73s	remaining: 366ms
# 94:	learn: 0.8931248	total: 5.81s	remaining: 306ms
# 95:	learn: 0.8926223	total: 5.87s	remaining: 244ms
# 96:	learn: 0.8918378	total: 5.92s	remaining: 183ms
# 97:	learn: 0.8909467	total: 5.96s	remaining: 122ms
# 98:	learn: 0.8898989	total: 6.01s	remaining: 60.7ms
# 99:	learn: 0.8889505	total: 6.06s	remaining: 0us

# %% [markdown]
# ### 성능 평가

# %%
score
# Out:
# {'svd': 3.239372605189222,
#  'coclu': 3.7927994286035283,
#  'lgbm_cl': 5.755384093460229,
#  'lgbm_r': 3.2005427265045934,
#  'catboost_cl': 5.691741438025897,
#  'catboost_r': 3.20149622525757,
#  'opt_weight': 3.170660569480184,
#  'combined_lgbm_cl': 3.639806864992686,
#  'combined_catboost_cl': 3.634724807719511}

# %% [markdown]
# 20세기의 경우, combined_lgbm_cl 보다 성능이 향상되지 않아, 다른 방식의 접근이 필요함을 알 수 있습니다.

# %%
rmse_v = rmse(y_test_20cent,lgbm_20cent_pred)
print(f"RMSE of Combined LGBM Classifier (CASE 20 Century): {round(rmse_v,4)}")
# Out:
# RMSE of Combined LGBM Classifier (CASE 20 Century): 3.6417

# %%
improved = rmse_v - score['combined_lgbm_cl']
print(f'Mixed improved RMSE {round(improved,4)}')
# Out:
# Mixed improved RMSE 0.0019

# %% [markdown]
# 21세기의 경우, combined_catboost_cl보다 평가 지표가 소폭 향상되었음을 확인할 수 있습니다.

# %%
rmse_v = rmse(y_test_21cent, catboost_21cent_pred.squeeze())
print(f"RMSE of Combined catboost Classifier (CASE 21 Century): {round(rmse_v,4)}")
# Out:
# RMSE of Combined catboost Classifier (CASE 21 Century): 3.6138

# %%
improved = rmse_v - score['combined_catboost_cl']
print(f'Mixed improved RMSE {round(improved,4)}')
# Out:
# Mixed improved RMSE -0.021

# %% [markdown]
# # [7] 결론

# %% [markdown]
# Hybrids 시스템은 전반적으로 강력한 시스템을 만드는 장점을 가지고 있습니다. 여기서 제시된 다양한 방법들은 추천시스템의 편향을 줄이거나 다양성을 통합하기 위해 사용됩니다.
#
# Hybrid Approach 또한 한가지 접근법만을 적용하는 것이 아닌 중첩하여 다양한 방식을 적용할 수도 있습니다.
#
# 최종적으로 Weighted, Feature Combine 방식을 모두 적용한 최종 output에 대해 살펴 보겠습니다.

# %%
score
# Out:
# {'svd': 3.239372605189222,
#  'coclu': 3.7927994286035283,
#  'lgbm_cl': 5.755384093460229,
#  'lgbm_r': 3.2005427265045934,
#  'catboost_cl': 5.691741438025897,
#  'catboost_r': 3.20149622525757,
#  'opt_weight': 3.170660569480184,
#  'combined_lgbm_cl': 3.639806864992686,
#  'combined_catboost_cl': 3.634724807719511}

# %%
threshold = 3.5
suitable_models = find_suitable_model(score,threshold)
print(f"RMSE {threshold} 이하 모델 활용 : {suitable_models}")
# Out:
# RMSE 3.5 이하 모델 활용 : ['svd', 'lgbm_r', 'catboost_r', 'opt_weight']

# %%
final_output_list = [pred[m] for m in suitable_models]

# %% [markdown]
# 다양한 모델에서 나온 결과값을 앙상블함으로서 보다 편향을 줄인 결과값을 얻을 수 있습니다.

# %%
optimal_weighted(final_output_list,n=100)
# Out:
# {'rmse': 3.1705785462625866,
#  'weight': array([0.152866  , 0.24632681, 0.01053962, 0.59026757])}

# %% [markdown]
# ---
# - reference
#   - Jeffery chiang, 7 Types of Hybrid Recommendation System
# , Jun 26, 2021, https://medium.com/analytics-vidhya/7-types-of-hybrid-recommendation-system-3e4f78266ad8

# %% [markdown]
# ---

# %% [markdown]
# <font color='red'><b>**WARNING**</b></font> : **본 교육 콘텐츠의 지식재산권은 재단법인 네이버커넥트에 귀속됩니다. 본 콘텐츠를 어떠한 경로로든 외부로 유출 및 수정하는 행위를 엄격히 금합니다.** 다만, 비영리적 교육 및 연구활동에 한정되어 사용할 수 있으나 재단의 허락을 받아야 합니다. 이를 위반하는 경우, 관련 법률에 따라 책임을 질 수 있습니다.
